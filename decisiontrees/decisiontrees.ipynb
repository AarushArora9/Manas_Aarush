# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
path='C:\\Users\\Hp\\Downloads\\Threats (1).csv'
df=pd.read_csv(path)
df
# Out:
#         Unnamed: 0      id       dur proto service state  spkts  dpkts  \
# 0            40000   40001  0.012996   tcp       -   FIN     16     18
# 1            40001   40002  0.004119   tcp       -   FIN     12     12
# 2            40002   40003  0.000988   udp     dns   CON      2      2
# 3            40003   40004  3.415787   tcp     ssh   FIN    230    238
# 4            40004   40005  0.193943   tcp       -   FIN     72     74
# ...            ...     ...       ...   ...     ...   ...    ...    ...
# 135336      175336  175337  0.000009   udp     dns   INT      2      0
# 135337      175337  175338  0.505762   tcp       -   FIN     10      8
# 135338      175338  175339  0.000009   udp     dns   INT      2      0
# 135339      175339  175340  0.000009   udp     dns   INT      2      0
# 135340      175340  175341  0.000009   udp     dns   INT      2      0
#
#         sbytes  dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0      id       dur proto service state  spkts  dpkts  \
# 0            40000   40001  0.012996   tcp       -   FIN     16     18
# 1            40001   40002  0.004119   tcp       -   FIN     12     12
# 2            40002   40003  0.000988   udp     dns   CON      2      2
# 3            40003   40004  3.415787   tcp     ssh   FIN    230    238
# 4            40004   40005  0.193943   tcp       -   FIN     72     74
# ...            ...     ...       ...   ...     ...   ...    ...    ...
# 135336      175336  175337  0.000009   udp     dns   INT      2      0
# 135337      175337  175338  0.505762   tcp       -   FIN     10      8
# 135338      175338  175339  0.000009   udp     dns   INT      2      0
# 135339      175339  175340  0.000009   udp     dns   INT      2      0
# 135340      175340  175341  0.000009   udp     dns   INT      2      0
#
#         sbytes  dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df_encoded=df.apply(l.fit_transform)
df_encoded
df= df_encoded
df
# Out:
#         Unnamed: 0      id    dur  proto  service  state  spkts  dpkts  \
# 0                0       0    328    111        0      1      9     10
# 1                1       1    234    111        0      1      7      7
# 2                2       2     70    117        2      0      1      2
# 3                3       3  44340    111       11      1    116    119
# 4                4       4   1877    111        0      1     38     38
# ...            ...     ...    ...    ...      ...    ...    ...    ...
# 135336      135336  135336      9    117        2      2      1      0
# 135337      135337  135337  11060    111        0      1      6      5
# 135338      135338  135338      9    117        2      2      1      0
# 135339      135339  135339      9    117        2      2      1      0
# 135340      135340  135340      9    117        2      2      1      0
#
#         sbytes  dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %%
df['proto'].unique()
# Out:
# array([111, 117,   6,  77,  41,  20,  52,  12, 126,  86, 124,  71,  82,
#         92,  15, 108,  59, 129,  43, 118,  67,   0,  55,  39,   9, 109,
#         61,  16,  89, 125, 122,  36,  22,  24,   7,  31,  81,  98,  78,
#         38, 130,  90,  70,  73,  28,  80,  45,  53,  91,  54, 102,  46,
#         10, 116, 110,  75, 103,   2,  93,  95,  87,  94,  27,   5,  79,
#         14, 123,  35, 107,  62, 105, 100,  58, 101,  29,  84,  17, 104,
#         66,  37,  99,   3,  63,  47,  69,  26,  40, 113,   1,  51,  34,
#         56,  96, 112,  32,  68,  21,  50, 121,  97, 119, 120,  18,  48,
#         30,  44,  49, 106,   4,   8,  23,  25,  42,  76,  85, 127,  13,
#         72,  19,  33,  83, 114, 128,  64,  65,  88,  57,  60,  74, 115,
#         11])

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
df_cleaned = df.drop(columns=['id', 'label', 'attack_cat'])
df_encoded = pd.get_dummies(df_cleaned, drop_first=True)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_encoded)
pca = PCA(n_components=5)  
pca_result = pca.fit_transform(scaled_data)
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2','3','4','5'])
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
pca_df['label'] = df['label'].values
import matplotlib.pyplot as plt

plt.scatter(pca_df['PC1'], pca_df['3'], c=pca_df['label'])
plt.title('PCA of Network Traffic Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Label')
plt.show()
# Out:
# Explained Variance Ratio: [0.39116664 0.10950128 0.08783798 0.06926395 0.05939287]

# %%
df_cleaned=df.drop(df.columns[[0,0]],axis=1)
df_cleaned=df_cleaned.drop(columns=['id','attack_cat'])
df_cleaned
# Out:
#           dur  proto  service  state  spkts  dpkts  sbytes  dbytes   rate  \
# 0         328    111        0      1      9     10     745     707  47576
# 1         234    111        0      1      7      7     504    1015  47834
# 2          70    117        2      0      1      2      42      33  47683
# 3       44340    111       11      1    116    119    4198    4149  46614
# 4        1877    111        0      1     38     38    2075    4955  47385
# ...       ...    ...      ...    ...    ...    ...     ...     ...    ...
# 135336      9    117        2      2      1      0      26       0  47941
# 135337  11060    111        0      1      6      5     275      62  30304
# 135338      9    117        2      2      1      0      26       0  47941
# 135339      9    117        2      2      1      0      26       0  47941
# 135340      9    117        2      2      1      0      26       0  47941
#
#         sttl  ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
target=df['attack_cat']
target
# Out:
# 0         6
# 1         6
# 2         6
# 3         6
# 4         6
#          ..
# 135336    5
# 135337    8
# 135338    5
# 135339    5
# 135340    5
# Name: attack_cat, Length: 135341, dtype: int32

# %%
model.fit(df_cleaned,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(df_cleaned,target)
# Out:
# 0.882578080552087

# %%
x=df_cleaned
y=target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model.fit(X_train,y_train)
print(model.score(X_train,y_train))
y_pred=model.predict(X_test)
#print(y_pred)
y_pred_prob = model.predict_proba(X_test)[:, 1]
#y_pred_prob
print(f"True attack_cat (y_test): \n{y_test}")
print(f"Predicted attack_cat (y_pred): \n{y_pred}")
# Out:
# 0.8857599379340919
# True attack_cat (y_test):
# 67768     6
# 101533    3
# 55401     3
# 20633     7
# 104215    5
#          ..
# 102158    2
# 134323    5
# 133594    5
# 57520     3
# 40835     0
# Name: attack_cat, Length: 27069, dtype: int32
# Predicted attack_cat (y_pred):
# [6 3 3 ... 5 7 0]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, f1_score, matthews_corrcoef, recall_score, accuracy_score
import numpy as np
X = df_cleaned
y = target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred_prob = model.predict_proba(X_test)
roc_auc = roc_auc_score(y_test, y_pred_prob, multi_class='ovr', average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='weighted')
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"AUC: {roc_auc}")
print(f"F1 Score: {f1}")
print(f"MCC: {mcc}")
print(f"Recall: {recall}")
# Out:
# Accuracy: 0.8116295393254276
# AUC: 0.9248099592879865
# F1 Score: 0.8103774879616211
# MCC: 0.7648743029280106
# Recall: 0.8116295393254276

# %%
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, VotingClassifier
bagging = BaggingClassifier(model, n_estimators=100, n_jobs=-1)
boosting = AdaBoostClassifier(model, n_estimators=100)
voting_classifier = VotingClassifier(estimators=[
    ('bagging', bagging),
    ('boosting', boosting)
], voting='hard')
voting_classifier.fit(X_train, y_train)
y_pred = voting_classifier.predict(X_test)
print("Voting Classifier Accuracy (Bagging + Boosting):", accuracy_score(y_test, y_pred))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Voting Classifier Accuracy (Bagging + Boosting): 0.8223059588459123

# %%
bagging = BaggingClassifier(model, n_estimators=100,n_jobs=-1)
bagging.fit(X_train,y_train)
print(bagging.score(X_test,y_test))
print(bagging.score(X_train,y_train))
# Out:
# 0.827404041523514
# 0.8854366779961578

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1)
g=GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_pred = gb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8340537145812553

# %%
import xgboost as xgb
xg=xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42, n_jobs=-1)
xg.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.810669030994865

# %%
from catboost import CatBoostClassifier

cat=CatBoostClassifier(iterations=100, learning_rate=0.1, depth=10, random_state=42, thread_count=-1, cat_features=[])
cat.fit(X_train,y_train)
y_pred=cat.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# 0:	learn: 1.7233163	total: 785ms	remaining: 1m 17s
# 1:	learn: 1.4719496	total: 1.47s	remaining: 1m 11s
# 2:	learn: 1.3018164	total: 2.16s	remaining: 1m 9s
# 3:	learn: 1.1743288	total: 2.82s	remaining: 1m 7s
# 4:	learn: 1.0767334	total: 3.46s	remaining: 1m 5s
# 5:	learn: 0.9958054	total: 4.15s	remaining: 1m 5s
# 6:	learn: 0.9289192	total: 4.89s	remaining: 1m 4s
# 7:	learn: 0.8737848	total: 5.65s	remaining: 1m 4s
# 8:	learn: 0.8261806	total: 6.36s	remaining: 1m 4s
# 9:	learn: 0.7860018	total: 7.02s	remaining: 1m 3s
# 10:	learn: 0.7514018	total: 7.73s	remaining: 1m 2s
# 11:	learn: 0.7212580	total: 8.35s	remaining: 1m 1s
# 12:	learn: 0.6942912	total: 9.01s	remaining: 1m
# 13:	learn: 0.6709816	total: 10.2s	remaining: 1m 2s
# 14:	learn: 0.6504286	total: 12.4s	remaining: 1m 10s
# 15:	learn: 0.6318485	total: 14.8s	remaining: 1m 17s
# 16:	learn: 0.6150064	total: 16.9s	remaining: 1m 22s
# 17:	learn: 0.5999885	total: 19.1s	remaining: 1m 27s
# ...
